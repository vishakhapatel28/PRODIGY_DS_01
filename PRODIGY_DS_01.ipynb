# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\visha\Downloads\API_SP.POP.TOTL_DS2_en_csv_v2_87 (1)\API_SP.POP.TOTL_DS2_en_csv_v2_87.csv",skiprows=4)
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2020                1
# 2021                1
# 2022                1
# 2023                1
# Unnamed: 68       266
# Length: 69, dtype: int64

# %%
df_1=df[["Country Name","Country Code","2020"]]
df_1.head()
# Out:
#                   Country Name Country Code         2020
# 0                        Aruba          ABW     108587.0
# 1  Africa Eastern and Southern          AFE  694446100.0
# 2                  Afghanistan          AFG   39068979.0
# 3   Africa Western and Central          AFW  474569351.0
# 4                       Angola          AGO   33451132.0

# %%
df_1.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 2020            1
# dtype: int64

# %%
selected_countries = ["India", "United States", "China", "Brazil", "Germany"]
df_filtered = df_1[df_1["Country Name"].isin(selected_countries)]

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="Country Name", y="2020", data=df_filtered)
plt.xlabel("Country")
plt.ylabel("Population in 2020")
plt.title("Population of Selected Countries in 2020")
plt.xticks(rotation=45)
plt.show()

# %%
df = df.drop(columns=["Indicator Name"], errors="ignore")

# %%
year_columns = [col for col in df.columns if col.isdigit()]

# %%
df_melted = df.melt(id_vars=["Country Name", "Country Code"], 
                    value_vars=year_columns, 
                    var_name="Year", value_name="Population")

# %%
df_melted
# Out:
#                       Country Name Country Code  Year   Population
# 0                            Aruba          ABW  1960      54922.0
# 1      Africa Eastern and Southern          AFE  1960  130072080.0
# 2                      Afghanistan          AFG  1960    9035043.0
# 3       Africa Western and Central          AFW  1960   97630925.0
# 4                           Angola          AGO  1960    5231654.0
# ...                            ...          ...   ...          ...
# 17019                       Kosovo          XKX  2023    1756366.0
# 17020                  Yemen, Rep.          YEM  2023   39390799.0
# 17021                 South Africa          ZAF  2023   63212384.0
# 17022                       Zambia          ZMB  2023   20723965.0
# 17023                     Zimbabwe          ZWE  2023   16340822.0
#
# [17024 rows x 4 columns]

# %%
df_melted["Year"] = pd.to_numeric(df_melted["Year"], errors="coerce")  
df_melted.dropna(inplace=True)  
df_india = df_melted[df_melted["Country Name"] == "India"]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_india["Population"], bins=20, kde=True)
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.title("Population Distribution of India Over Time")
plt.show()
